# %% [markdown]
# 1. Add the current date to the text file today.txt as a string.

# %%
import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 25-09-2023

# %% [markdown]
# 2. Read the text file today.txt into the string today_string

# %%
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 25-09-2023

# %% [markdown]
# 3. Parse the date from today_string.

# %%
from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2023-09-25 00:00:00

# %% [markdown]
# 4. List the files in your current directory

# %%
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# 1694331410160UhHD6KVaKMxfyFOI.pdf
# 1694331436378qv3D8xvkpDs8CCes.pdf
# 24240985 (1).pdf
# 24240985.pdf
# application_log.txt
# assignment 10 (1).ipynb
# assignment 10.ipynb
# assignment 11 (1).ipynb
# assignment 11.ipynb
# assignment 12 (1).ipynb
# assignment 12 (2).ipynb
# assignment 12.ipynb
# assignment 13 (1).ipynb
# assignment 13.ipynb
# assignment 14 (1).ipynb
# assignment 14.ipynb
# assignment 15 (1).ipynb
# assignment 15.ipynb
# assignment 16.ipynb
# assignment 17 (1).ipynb
# assignment 17.ipynb
# assignment 18.ipynb
# assignment 19.ipynb
# assignment 20.ipynb
# assignment 21.ipynb
# assignment 6 (1).ipynb
# assignment 6.ipynb
# assignment 7 (1).ipynb
# assignment 7 (2).ipynb
# assignment 7.ipynb
# assignment 8 (1).ipynb
# assignment 8.ipynb
# assignment 9 (1).ipynb
# assignment 9.ipynb
# aug-sep.xls
# books.csv
# books.db
# CitrixWorkspaceApp.exe
# Credit Card Authorization Form_Nov2020 (2).pdf
# Credit Card Authorization Form_Nov2020.pdf
# Data Analyst - Sample Resume 1.docx
# Data Scientist Resume 3 (1).docx
# desktop.ini
# EDUCO CONSENT FORM (1).pdf
# EDUCO CONSENT FORM.pdf
# Experience Letter.pdf
# J SAI MAHESH KUMAR FORM16.pdf
# JammSaiRelLetter (1).pdf
# JammSaiRelLetter.docx
# JammSaiRelLetter.pdf
# july.xls
# LOR#1.pdf
# LOR#2.pdf
# marriage.pdf
# mtputty_setup.exe
# npp.8.5.7.Installer.x64.exe
# Q0MtQ0xULUFELldpbmRvd3MgMTAgQ2xvdWQgJEEyMC0xNy0xN0RGNjgzNC0wMDAx (1).ica
# Q0MtQ0xULUFELldpbmRvd3MgMTAgQ2xvdWQgJEEyMC0xNy0xN0RGNjgzNC0wMDAx (2).ica
# Q0MtQ0xULUFELldpbmRvd3MgMTAgQ2xvdWQgJEEyMC0xNy0xN0RGNjgzNC0wMDAx (3).ica
# Q0MtQ0xULUFELldpbmRvd3MgMTAgQ2xvdWQgJEEyMC0xNy0xN0RGNjgzNC0wMDAx (4).ica
# exceptional handling (1).ipynb
# exceptional handling.ipynb
# Final resume.docx
# functions.ipynb
# Fw__RECRUITMENT_OF_CHIEF_MANAGERS_IN_SENIOR_MANAGEMENT_GRADE_SCALE_IV_AND_SENIOR_MANAGERS_IN_MIDDLE_MANAGEMENT_GRADE_SCALE_III_IN_MAINSTREAM. (1).zip
# HIKE Letter.docx
# hr sign22.jpg
# IBAWindowsLauncher.zip
# IBM_Install_DD (1).jnlp
# IBM_Install_DD.jnlp
# Identity Card.jpeg
# ietrator,generator,map,reduce,filter,basic file,operation (1) (1).ipynb
# ietrator,generator,map,reduce,filter,basic file,operation (1).ipynb
# ietrator,generator,map,reduce,filter,basic file,operation.ipynb
# IHP Hike Letter.pdf
# IHP Hike Letter_page-0001.jpg
# ilovepdf_pages-to-jpg.zip
# image.png
# IMG-20220926-WA0000.jpg
# img20190716_14290268.jpg
# IMG20210415214815.jpg
# IMG_20220424_202736_864 (1).jpg
# IMG_20220424_202736_864 (2).jpg
# IMG_20220424_202736_864.jpg
# interview-schedule.ics
# invite (1).ics
# invite (2).ics
# invite.ics
# IOMP[1] (1).pptx
# IOMP[1] [Autosaved].pptx
# IOMP[1].pptx
# Jammi.docx
# JammSaiRelLetter (1).pdf
# JammSaiRelLetter.pdf
# journal sriya.docx
# journal sriya.pdf
# Journal_Sriya_Soft Storey.docx
# jre-8u361-windows-x64.exe
# June 2022.pdf
# K.Sriya Resume (1).docx
# K.Sriya Resume (1).pdf
# K.Sriya Resume.docx
# K.Sriya Resume.pdf
# k.sriya,19AG1A0112, civil2A.pdf
# kaleshwaram project.pdf
# KAREE-SRIYA.pdf
# lasyapriya seminar ppt.pptx
# LockDownBrowserOEMSetup.exe
# logging.ipynb
# loops (1).ipynb
# loops task (1) (1).ipynb
# loops task (1).ipynb
# loops task.ipynb
# loops.ipynb
# MAJOR PROJECT SRIYA (1).pptx
# MAJOR PROJECT SRIYA (2).pptx
# MAJOR PROJECT SRIYA (3).pptx
# MAJOR PROJECT SRIYA (4).pptx
# MAJOR PROJECT SRIYA.pptx
# MANUAL CALCULATION SHEETS PROJECT.xlsx
# MANUAL CALCULATION SHEETS.xlsx
# McGraw-Hill Education 6 IELTS Practice Tests Book (1).pdf
# McGraw-Hill Education 6 IELTS Practice Tests Book.pdf
# MDP Associate- Job Description (1) (1).pdf
# MDP Associate- Job Description (1) (2).pdf
# MDP Associate- Job Description (1).pdf
# MEGA-RECOVERYKEY.txt
# miniproject docn.docx
# miniproject_documentation.pdf
# MobaXterm_Installer_v22.3.zip
# mongosh-1.7.1-win32-x64.zip
# Morningstar Development Program - One Pager (1) (1).pdf
# Morningstar Development Program - One Pager (1).pdf
# MQ (1).rar
# MQ.rar
# my-passport-photo.jpg
# mysql-connector-python-8.0.30 (1).tar.gz
# mysql-connector-python-8.0.30.tar.gz
# mysql.7z
# mysql.zip
# notice_mts_18012023.pdf
# Sriya _CIVIL_Resume.pdf
# Sriya+Resume+F+(1).pdf
# sriyair1build.pdf
# sriyaresume.docx
# sriyaresume.pdf
# SRIYA_Aadhar.pdf
# SRIYA_BIRTH CERTIFICATE.pdf
# Sriya_Civil.docx
# sriya_photo.jpg
# Sriya_Resume (1).pdf
# Sriya_Resume.docx
# Sriya_Resume.pdf
# SSMS-Setup-ENU.exe
# student_scores.csv
# sudh1.txt
# task1.ipynb
# TeamsSetupx64_s_8DA86833DAC7932-7-0_c_w_.exe
# TeamsSetupx64_s_8DB2C20F57E25E6-1-0_c_w_.exe
# test.sri
# test.text
# test.txt
# test1.txt
# test2.txt
# test5.txt
# TIAA+India+Candidate+Benefits+Document+-+v.2022 (1).pdf
# TIAA+India+Candidate+Benefits+Document+-+v.2022.pdf
# TIAA+India+–+Relocation+&+Transfer+Assistance+Document (1).pdf
# TIAA+India+–+Relocation+&+Transfer+Assistance+Document (2).pdf
# TIAA+India+–+Relocation+&+Transfer+Assistance+Document.pdf
# TotalAV_Setup.exe
# trade_details_EEEXXXXX3Q_2829271283.pdf
# trade_details_EEEXXXXX3Q_2829271283_unlocked.pdf
# trade_details_EEEXXXXX3Q_2829271283_unlocked.xlsx
# UDAYPROJECTPPT (1).pptx
# UDAYPROJECTPPT.pptx
# Untitled design.pdf
# Untitled5.ipynb
# Untitled6.ipynb
# Vendor Training.ppt
# VisualStudioSetup.exe
# vnd.openxmlformats-officedocument.wordprocessingml (1).pdf
# vnd.openxmlformats-officedocument.wordprocessingml (2).pdf
# vnd.openxmlformats-officedocument.wordprocessingml (3).pdf
# vnd.openxmlformats-officedocument.wordprocessingml (4).pdf
# vnd.openxmlformats-officedocument.wordprocessingml.pdf
# WhatsApp Image 2023-07-13 at 12.23.35 PM (2).jpeg
# writing task 2.txt
# zoom.apk
# ZoomCitrixHDXMediaPlugin.msi
# [Secure Email] Welcome to TIAA GBS.eml
# _in1.csv
# conditions-checkpoint.ipynb
# exceptional handling (1) (1)-checkpoint.ipynb
# exceptional handling (1)-checkpoint.ipynb
# exceptional handling-checkpoint.ipynb
# functions-checkpoint.ipynb
# ietrator,generator,map,reduce,filter,basic file,operation (1) (1)-checkpoint.ipynb
# ietrator,generator,map,reduce,filter,basic file,operation (1)-checkpoint.ipynb
# ietrator,generator,map,reduce,filter,basic file,operation-checkpoint.ipynb
# logging-checkpoint.ipynb
# loops (1)-checkpoint.ipynb
# loops task (1) (1)-checkpoint.ipynb
# loops task (1)-checkpoint.ipynb
# loops task-checkpoint.ipynb
# loops-checkpoint.ipynb
# task1-checkpoint.ipynb
# test-checkpoint.ipynb
# Untitled-checkpoint.ipynb
# Untitled2-checkpoint.ipynb
# Untitled3-checkpoint.ipynb
# Untitled4-checkpoint.ipynb
# Untitled5-checkpoint.ipynb
# Untitled6-checkpoint.ipynb
# Untitled design_page-0001.jpg
# Untitled design_page-0002.jpg
# Untitled design_page-0003.jpg
# Untitled design_page-0004.jpg
# LICENSE-crypt-library
# LICENSE-mongosh
# mongosh.1.gz
# README
# THIRD_PARTY_NOTICES
# mongosh.exe
# mongosh_crypt_v1.dll
# E_LOR 1 BS.docx
# E_LOR 2 AK.docx
# LOR 3 HOD.docx
# LOR 1 BS.docx
# LOR 2 AK.docx
# LOR 3 HOD.docx
# LOR 1 BS (1).docx
# LOR 1 BS.docx
# LOR 2 AK.docx
# LOR 3 HOD.docx

# %% [markdown]
# 5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
import os 
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1694331410160UhHD6KVaKMxfyFOI.pdf',
#  '1694331436378qv3D8xvkpDs8CCes.pdf',
#  '24240985 (1).pdf',
#  '24240985.pdf',
#  'application_log.txt',
#  'assignment 10 (1).ipynb',
#  'assignment 10.ipynb',
#  'assignment 11 (1).ipynb',
#  'assignment 11.ipynb',
#  'assignment 12 (1).ipynb',
#  'assignment 12 (2).ipynb',
#  'assignment 12.ipynb',
#  'assignment 13 (1).ipynb',
#  'assignment 13.ipynb',
#  'assignment 14 (1).ipynb',
#  'assignment 14.ipynb',
#  'assignment 15 (1).ipynb',
#  'assignment 15.ipynb',
#  'assignment 16.ipynb',
#  'assignment 17 (1).ipynb',
#  'assignment 17.ipynb',
#  'assignment 18.ipynb',
#  'assignment 19.ipynb',
#  'assignment 20.ipynb',
#  'assignment 21.ipynb',
#  'assignment 6 (1).ipynb',
#  'assignment 6.ipynb',
#  'assignment 7 (1).ipynb',
#  'assignment 7 (2).ipynb',
#  'assignment 7.ipynb',
#  'assignment 8 (1).ipynb',
#  'assignment 8.ipynb',
#  'assignment 9 (1).ipynb',
#  'assignment 9.ipynb',
#  'aug-sep.xls',
#  'books.csv',
#  'books.db',
#  'CitrixWorkspaceApp.exe',
#  'Credit Card Authorization Form_Nov2020 (2).pdf',
#  'Credit Card Authorization Form_Nov2020.pdf',
#  'Data Analyst - Sample Resume 1.docx',
#  'Data Scientist Resume 3 (1).docx',
#  'desktop.ini',
#  'downloads',
#  'edited lor',
#  'EDUCO CONSENT FORM (1).pdf',
#  'EDUCO CONSENT FORM.pdf',
#  'Experience Letter.pdf',
#  'J SAI MAHESH KUMAR FORM16.pdf',
#  'JammSaiRelLetter (1).pdf',
#  'JammSaiRelLetter.docx',
#  'JammSaiRelLetter.pdf',
#  'july.xls',
#  'LOR',
#  'LOR#1.pdf',
#  'LOR#2.pdf',
#  'lor2',
#  'marriage.pdf',
#  'mtputty_setup.exe',
#  'npp.8.5.7.Installer.x64.exe',
#  'Q0MtQ0xULUFELldpbmRvd3MgMTAgQ2xvdWQgJEEyMC0xNy0xN0RGNjgzNC0wMDAx (1).ica',
#  'Q0MtQ0xULUFELldpbmRvd3MgMTAgQ2xvdWQgJEEyMC0xNy0xN0RGNjgzNC0wMDAx (2).ica',
#  'Q0MtQ0xULUFELldpbmRvd3MgMTAgQ2xvdWQgJEEyMC0xNy0xN0RGNjgzNC0wMDAx (3).ica',
#  'Q0MtQ0xULUFELldpbmRvd3MgMTAgQ2xvdWQgJEEyMC0xNy0xN0RGNjgzNC0wMDAx (4).ica',
#  'Q0MtQ0xULUFELldpbmRvd3MgMTAgQ2xvdWQgJEEyMC0xNy0xN0RGNjgzNC0wMDAx (5).ica',
#  'Q0MtQ0xULUFELldpbmRvd3MgMTAgQ2xvdWQgJEEyMC0xNy0xN0RGNjgzNC0wMDAx (7).ica',
#  'Q0MtQ0xULUFELldpbmRvd3MgMTAgQ2xvdWQgJEEyMC0xNy0xN0RGNjgzNC0wMDAx.ica',
#  'Ramya_GIS_Resume.docx',
#  'Relieving Letter.pdf',
#  'Resume-Sriya (1) (1).pdf',
#  'Resume-Sriya (1).pdf',
#  'Resume-Sriya.docx',
#  'Resume-Sriya.pdf',
#  'Sai Mahesh_ATMT Details.docx',
#  'sneha resume.pdf',
#  'SOP Questionnaire new 7th Jan (1) (1) (1) (2) (1).docx',
#  'sriya passport back.jpeg',
#  'Sriya passport front.jpeg',
#  'sriya __SOP.pdf',
#  'Sriya_DataScience Resume.docx',
#  'Sriya_DataScience Resume.pdf',
#  'Student Information form (2) (1).doc',
#  'Student Information form (2).doc',
#  'test.txt',
#  'today.txt',
#  'UMBCG2_90321333_20230912101821.pdf',
#  'university_records.csv',
#  'UNT DS SOP-Sriya.pdf',
#  'Untitled (1).ipynb',
#  'Untitled (2).ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  '~$sume-Sriya.docx',
#  '~WRL0005.tmp']

# %% [markdown]
# 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing
import time 
import random
import datetime

def procOne():
    print(f'Proc_one_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_one_Endtime -> {datetime.datetime.now()}')
    
def procTwo():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')

def procThree():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=procOne)
    p2 = multiprocessing.Process(target=procTwo)
    p3 = multiprocessing.Process(target=procThree)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()

# %% [markdown]
# 7. Create a date object of your day of birth.

# %%
from datetime import datetime
my_dob = datetime.strptime('22/04/1997','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 1997-04-22 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# 8. What day of the week was your day of birth?

# %%
from datetime import datetime
my_dob = datetime(1997,4,22)
my_dob.strftime("%A")
# Out:
# 'Tuesday'

# %% [markdown]
# 9. When will you be (or when were you) 10,000 days old?

# %%
from datetime import datetime, timedelta
my_dob = datetime.strptime("22/04/1997",'%d/%m/%Y')
future_date = my_dob-timedelta(10000)
future_date
# Out:
# datetime.datetime(1969, 12, 5, 0, 0)
